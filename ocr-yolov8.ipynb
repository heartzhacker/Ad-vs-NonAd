# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.9-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.4)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.24.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.6.0.66)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2023.12.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.1.9-py3-none-any.whl (709 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 23.4 MB/s eta 0:00:00
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.9

# %%
# !pip install paddleocr
# Out:
# Requirement already satisfied: paddleocr in /opt/conda/lib/python3.10/site-packages (2.7.0.3)
# Requirement already satisfied: shapely in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.8.5.post1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.22.0)
# Requirement already satisfied: imgaug in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.4.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.24.4)
# Requirement already satisfied: visualdl in /opt/conda/lib/python3.10/site-packages (from paddleocr) (2.5.3)
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.6.1)
# Requirement already satisfied: opencv-python<=4.6.0.66 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: opencv-contrib-python<=4.6.0.66 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.0.8)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from paddleocr) (5.1.0)
# Requirement already satisfied: premailer in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.10.0)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.1.2)
# Requirement already satisfied: attrdict in /opt/conda/lib/python3.10/site-packages (from paddleocr) (2.0.1)
# Requirement already satisfied: PyMuPDF<1.21.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.20.2)
# Requirement already satisfied: Pillow>=10.0.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (10.2.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from paddleocr) (6.0.1)
# Requirement already satisfied: python-docx in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.12.2)
# Requirement already satisfied: fonttools>=4.24.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.47.0)
# Requirement already satisfied: fire>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.5.0)
# Requirement already satisfied: pdf2docx in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.5.8)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->paddleocr) (2.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from imgaug->paddleocr) (1.11.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from imgaug->paddleocr) (3.7.4)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.10/site-packages (from imgaug->paddleocr) (2.33.1)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (0.3)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from openpyxl->paddleocr) (1.1.0)
# Requirement already satisfied: opencv-python-headless>=4.5 in /opt/conda/lib/python3.10/site-packages (from pdf2docx->paddleocr) (4.9.0.80)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from python-docx->paddleocr) (4.9.0)
# Requirement already satisfied: cssselect in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (1.2.0)
# Requirement already satisfied: cssutils in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (2.9.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (2.31.0)
# Requirement already satisfied: cachetools in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (4.2.4)
# Requirement already satisfied: bce-python-sdk in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (0.9.4)
# Requirement already satisfied: flask>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (3.0.1)
# Requirement already satisfied: Flask-Babel>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (4.0.0)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (3.20.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (2.1.4)
# Requirement already satisfied: rarfile in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (4.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (5.9.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (1.7.0)
# Requirement already satisfied: Babel>=2.12 in /opt/conda/lib/python3.10/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2.14.0)
# Requirement already satisfied: pytz>=2022.7 in /opt/conda/lib/python3.10/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2023.3.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->paddleocr) (3.1.1)
# Requirement already satisfied: pycryptodome>=3.8.0 in /opt/conda/lib/python3.10/site-packages (from bce-python-sdk->visualdl->paddleocr) (3.20.0)
# Requirement already satisfied: future>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from bce-python-sdk->visualdl->paddleocr) (0.18.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->visualdl->paddleocr) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr) (2.1.3)

# %%
pip install paddlepaddle
# Out:
# Requirement already satisfied: paddlepaddle in /opt/conda/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (0.26.0)
# Requirement already satisfied: numpy>=1.13 in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (1.24.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (10.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (5.1.1)
# Requirement already satisfied: astor in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from paddlepaddle) (3.20.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->paddlepaddle) (4.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->paddlepaddle) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->paddlepaddle) (1.0.2)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->paddlepaddle) (3.6)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->paddlepaddle) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->paddlepaddle) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->paddlepaddle) (4.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install paddleocr --upgrade
# Out:
# Requirement already satisfied: paddleocr in /opt/conda/lib/python3.10/site-packages (2.7.0.3)
# Requirement already satisfied: shapely in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.8.5.post1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.22.0)
# Requirement already satisfied: imgaug in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.4.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.24.4)
# Requirement already satisfied: visualdl in /opt/conda/lib/python3.10/site-packages (from paddleocr) (2.5.3)
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.6.1)
# Requirement already satisfied: opencv-python<=4.6.0.66 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: opencv-contrib-python<=4.6.0.66 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.0.8)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from paddleocr) (5.1.0)
# Requirement already satisfied: premailer in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.10.0)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.10/site-packages (from paddleocr) (3.1.2)
# Requirement already satisfied: attrdict in /opt/conda/lib/python3.10/site-packages (from paddleocr) (2.0.1)
# Requirement already satisfied: PyMuPDF<1.21.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.20.2)
# Requirement already satisfied: Pillow>=10.0.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (10.2.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from paddleocr) (6.0.1)
# Requirement already satisfied: python-docx in /opt/conda/lib/python3.10/site-packages (from paddleocr) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.12.2)
# Requirement already satisfied: fonttools>=4.24.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (4.47.0)
# Requirement already satisfied: fire>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.5.0)
# Requirement already satisfied: pdf2docx in /opt/conda/lib/python3.10/site-packages (from paddleocr) (0.5.8)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->paddleocr) (2.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from imgaug->paddleocr) (1.11.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from imgaug->paddleocr) (3.7.4)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.10/site-packages (from imgaug->paddleocr) (2.33.1)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->paddleocr) (0.3)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from openpyxl->paddleocr) (1.1.0)
# Requirement already satisfied: opencv-python-headless>=4.5 in /opt/conda/lib/python3.10/site-packages (from pdf2docx->paddleocr) (4.9.0.80)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from python-docx->paddleocr) (4.9.0)
# Requirement already satisfied: cssselect in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (1.2.0)
# Requirement already satisfied: cssutils in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (2.9.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (2.31.0)
# Requirement already satisfied: cachetools in /opt/conda/lib/python3.10/site-packages (from premailer->paddleocr) (4.2.4)
# Requirement already satisfied: bce-python-sdk in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (0.9.4)
# Requirement already satisfied: flask>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (3.0.1)
# Requirement already satisfied: Flask-Babel>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (4.0.0)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (3.20.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (2.1.4)
# Requirement already satisfied: rarfile in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (4.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from visualdl->paddleocr) (5.9.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr) (1.7.0)
# Requirement already satisfied: Babel>=2.12 in /opt/conda/lib/python3.10/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2.14.0)
# Requirement already satisfied: pytz>=2022.7 in /opt/conda/lib/python3.10/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2023.3.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->paddleocr) (3.1.1)
# Requirement already satisfied: pycryptodome>=3.8.0 in /opt/conda/lib/python3.10/site-packages (from bce-python-sdk->visualdl->paddleocr) (3.20.0)
# Requirement already satisfied: future>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from bce-python-sdk->visualdl->paddleocr) (0.18.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->visualdl->paddleocr) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->premailer->paddleocr) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO('/kaggle/input/yolov8/best.pt') 
results = model(['/kaggle/input/adddddd/ad2.png'])
# Out:
# 0: 640x480 1 0, 55.3ms
# Speed: 8.3ms preprocess, 55.3ms inference, 513.5ms postprocess per image at shape (1, 3, 640, 480)

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: '0'}
#  obb: None
#  orig_img: array([[[137, 135,  61],
#          [137, 135,  61],
#          [138, 135,  61],
#          ...,
#          [138, 135,  61],
#          [138, 135,  61],
#          [138, 135,  61]],
#
#         [[137, 135,  61],
#          [138, 135,  61],
#          [137, 135,  61],
#          ...,
#          [138, 135,  61],
#          [138, 135,  61],
#          [138, 135,  61]],
#
#         [[137, 135,  61],
#          [138, 135,  61],
#          [138, 135,  61],
#          ...,
#          [137, 134,  61],
#          [137, 134,  61],
#          [138, 134,  61]],
#
#         ...,
#
#         [[138, 135,  61],
#          [138, 135,  61],
#          [137, 134,  60],
#          ...,
#          [138, 135,  61],
#          [138, 135,  61],
#          [138, 135,  61]],
#
#         [[138, 134,  60],
#          [138, 135,  60],
#          [138, 135,  61],
#          ...,
#          [138, 135,  61],
#          [138, 135,  61],
#          [138, 135,  61]],
#
#         [[137, 135,  60],
#          [138, 135,  61],
#          [138, 135,  60],
#          ...,
#          [139, 136,  62],
#          [139, 136,  62],
#          [139, 136,  62]]], dtype=uint8)
#  orig_shape: (600, 428)
#  path: '/kaggle/input/adddddd/ad2.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 8.341073989868164, 'inference': 55.32360076904297, 'postprocess': 513.4501457214355}]

# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /opt/conda/lib/python3.10/site-packages (1.7.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: torchvision>=0.5 in /opt/conda/lib/python3.10/site-packages (from easyocr) (0.16.2)
# Requirement already satisfied: opencv-python-headless in /opt/conda/lib/python3.10/site-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from easyocr) (1.11.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from easyocr) (1.24.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from easyocr) (10.2.0)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from easyocr) (0.22.0)
# Requirement already satisfied: python-bidi in /opt/conda/lib/python3.10/site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.10/site-packages (from easyocr) (1.8.5.post1)
# Requirement already satisfied: pyclipper in /opt/conda/lib/python3.10/site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in /opt/conda/lib/python3.10/site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr) (0.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->easyocr) (2023.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->easyocr) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->easyocr) (1.3.0)

# %%
import easyocr
import cv2
reader = easyocr.Reader(['en'])
image = cv2.imread('/kaggle/input/adddddd/ad2.png')
result = reader.readtext(image)
for detection in result:
    print(detection[1])
# Out:
# You Feel Like a Samurai
# BOSch
